# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Housing.csv")

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
df.replace({'yes':1,'no':0,'furnished':1,'semi-furnished':2,'unfurnished':0},inplace=True)

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus
# 0                 1
# 1                 1
# 2                 2
# 3                 1
# 4                 1

# %%
df.corr()
# Out:
#                      price      area  bedrooms  bathrooms   stories  mainroad  \
# price             1.000000  0.535997  0.366494   0.517545  0.420712  0.296898
# area              0.535997  1.000000  0.151858   0.193820  0.083996  0.288874
# bedrooms          0.366494  0.151858  1.000000   0.373930  0.408564 -0.012033
# bathrooms         0.517545  0.193820  0.373930   1.000000  0.326165  0.042398
# stories           0.420712  0.083996  0.408564   0.326165  1.000000  0.121706
# mainroad          0.296898  0.288874 -0.012033   0.042398  0.121706  1.000000
# guestroom         0.255517  0.140297  0.080549   0.126469  0.043538  0.092337
# basement          0.187057  0.047417  0.097312   0.102106 -0.172394  0.044002
# hotwaterheating   0.093073 -0.009229  0.046049   0.067159  0.018847 -0.011781
# airconditioning   0.452954  0.222393  0.160603   0.186915  0.293602  0.105423
# parking           0.384394  0.352980  0.139270   0.177496  0.045547  0.204433
# ...

# %%
x=df.drop('price',axis='columns')
x
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0    7420         4          2        3         1          0         0
# 1    8960         4          4        4         1          0         0
# 2    9960         3          2        2         1          0         1
# 3    7500         4          2        2         1          0         1
# 4    7420         4          1        2         1          1         1
# ..    ...       ...        ...      ...       ...        ...       ...
# 540  3000         2          1        1         1          0         1
# 541  2400         3          1        1         0          0         0
# 542  3620         2          1        1         1          0         0
# 543  2910         3          1        1         0          0         0
# 544  3850         3          1        2         1          0         0
#
#      hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# ...

# %%
y=df.price
y
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %%
plt.xlabel('bedrooms')
plt.ylabel('price')
plt.title('Relation among price and bedrooms')
plt.plot(df.bedrooms.head(30),df.price.head(30),color='b')

# %%
plt.xlabel('area')
plt.ylabel('price')
plt.title('Relation among price and area')
plt.plot(df.area.head(30),df.price.head(30),color='b')

# %%
import seaborn as sns
sns.pairplot(df)

# %%
sns.pairplot(df,kind='reg')

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,random_state=10,train_size=0.65)

# %%
from sklearn.linear_model import LinearRegression
linearmodel=LinearRegression()

# %%
linearmodel.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
ypredicted=linearmodel.predict(xtest)
ypredicted
# Out:
# array([ 2681913.37054389,  3860558.00688643,  5688084.57612137,
#         3824889.14556337,  6735380.66584017,  6622111.65319112,
#         3590086.19183002,  3123182.89832828,  5585836.6396922 ,
#         3225630.07085217,  4905256.77927899,  2171856.25338175,
#         4355153.92982109,  4791189.63202721,  6620033.58247524,
#         2452954.23033714,  7181269.3465288 ,  6598007.56742655,
#         5232522.46966929,  4486866.67651092,  2575353.96474765,
#         1991099.28418403,  5975721.40651924,  5695942.88271088,
#         6558406.2997348 ,  6305544.1709555 ,  3843369.78804761,
#         3709713.18585833,  3784865.64040447,  3725311.15538455,
#         4187469.73651905,  4650987.34809192,  5726103.05271457,
#         5506932.50421013,  7306350.50475251,  4830451.581685  ,
#         6483114.52477935,  2138837.88088494,  5016769.77165422,
#         5703244.01619199,  5024665.13100635,  5411516.49863863,
#         2899667.71356179,  6472085.6456601 ,  5686595.37333967,
# ...

# %%
linearmodel.score(xtest,ytest)
# Out:
# 0.7317786992118891
